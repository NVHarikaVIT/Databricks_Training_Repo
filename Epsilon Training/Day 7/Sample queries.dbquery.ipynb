-- %%
SELECT * FROM harika_silver.ecom_enriched;

SELECT 
  customer_id, 
  COUNT(customer_id) counts
FROM harika_silver.ecom_enriched
GROUP BY customer_id
ORDER BY counts DESC;
-- Out:
-- Databricks visualization. Run in Databricks to view.
