-- %%
%sql
use catalog dev;
use schema harika;

-- %%
%sql
create table if not exists people(id int, name string, age int);

-- %%
%sql
describe extended people;

-- %%
%sql
describe history people;

-- %%
%sql
insert into people values (1, 'John', 25);

describe history people;

-- %%
%sql
describe detail people;

-- %%
%sql
insert into people values (1, 'Jack', 25),(1,'George',30);

describe detail people;

-- %%
%sql
select * from people;

-- %%
%sql
insert into people values(1,'Darshan', 22);
insert into people values(1,'Harish', 22);
insert into people values(1,'Vaibhav', 22);
insert into people values(1,'peyush', 22);
insert into people values(1,'Divya', 22);
insert into people values(1,'Ankan', 22);
insert into people values(1,'Harika', 22);

-- %%
describe detail people;

-- %%
select * from people;

-- %%
-- Optimising the query performance
OPTIMIZE people;

-- %%
select * from people;

-- %%
optimize people
zorder by name;

-- %%
select * from people;

-- %%
delete from people where name="John";

-- %%
describe history people;

-- %%
restore table people to version as of 11;

-- %%
select * from people;

-- %%
-- We can reduce the storage space of unused files after optimisation using VACCUM.
VACUUM dev.harika.people

-- %%
VACUUM dev.harika.people RETAIN 0 HOURS

-- %%
SET delta.retentionDurationCheck.enabled = false

-- %%
-- Another example

CREATE TABLE IF NOT EXISTS dev.harika.orders AS 
SELECT * FROM samples.tpch.orders;

-- %%
select * from dev.harika.orders;

-- %%
-- Updating the records of the tables.
