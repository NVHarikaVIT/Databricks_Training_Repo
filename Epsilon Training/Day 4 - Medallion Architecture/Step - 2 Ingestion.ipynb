# %%
# %run "/Workspace/Users/nunevenkataharikaic@gmail.com/Epsilon Training/Day 4 - Medallion Architecture/Step - 1 Project Setup"

# %%
# %python
# Hard coated values
# catalog= "dev"
# schema="harika_bronze"
# table_name="sales"

# %%
# %python
# Dynamic values
dbutils.widgets.text("catalog","dev")
dbutils.widgets.text("schema","harika_bronze")
dbutils.widgets.text("table_name","sales")

# %%
catalog=dbutils.widgets.get("catalog")
schema=dbutils.widgets.get("schema")
table_name=dbutils.widgets.get("table_name")

# %%
#read/Extract
df=spark.read.csv(f"{input_path}{table_name}.csv",header=True,inferSchema=True)

#metadata
df1=add_column(df)

#write
df1.write.mode("overwrite").saveAsTable(f"{catalog}.{schema}.{table_name}")
