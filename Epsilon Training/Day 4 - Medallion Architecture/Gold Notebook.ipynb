# %%
# %sql
create or replace view dev.harika_gold.top_customers as
select customer_id, sum(total_amount) as total from dev.harika_silver.sales_cleaned group by customer_id order by total desc limit 3

# %%
# %sql
select * from dev.harika_gold.top_customers
