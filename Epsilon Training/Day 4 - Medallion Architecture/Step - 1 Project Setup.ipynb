-- %%
%python
from pyspark.sql.functions import *

-- %%
%python
input_path="/Volumes/dev/naval/raw/project/"

-- %%
use catalog dev;

-- %%
create schema if not exists harika_bronze;
create schema if not exists harika_silver;
create schema if not exists harika_gold;

-- %%
%python
def add_column(df):
  return df.withColumn("ingestion_date",current_timestamp()).withColumn("path",col("_metadata.file_name"))
