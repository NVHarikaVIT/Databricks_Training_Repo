# %%
df = spark.table("dev.harika_bronze.products")

# %%
df1=df.dropDuplicates().dropna().drop("ingestion_date","path")

# %%
df1.write.mode("overwrite").saveAsTable("dev.harika_silver.products_cleaned")
